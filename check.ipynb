# %%
import pandas as pd

df = pd.read_parquet("transactions_S.parquet")

print(df.head())
print(df.dtypes)
# Out:
#                    ts  user_id region event_type   value  \
# 0 2025-02-02 11:41:46   366324     CH   transfer  209.60
# 1 2025-10-09 17:16:48   490765     DE    payment   20.65
# 2 2025-08-27 06:20:12   174786     DE   transfer  473.98
# 3 2025-06-09 18:02:31    90782     FR    payment   17.49
# 4 2025-06-07 14:49:15   442919     UK    payment  104.86
#
#                                              payload
# 0   merchant=Apple;category=electronics;currency=CHF
# 1  merchant=Netflix;category=subscription;currenc...
# 2  merchant=Netflix;category=subscription;currenc...
# 3       merchant=SBB;category=transport;currency=EUR
# 4      merchant=Coop;category=groceries;currency=GBP
# ts            datetime64[ns]
# user_id                int64
# region                object
# event_type            object
# value                float64
# payload               object
# dtype: object

# %%
print(df.head(10))
# Out:
#                    ts  user_id region  event_type   value  \
# 0 2025-02-02 11:41:46   366324     CH    transfer  209.60
# 1 2025-10-09 17:16:48   490765     DE     payment   20.65
# 2 2025-08-27 06:20:12   174786     DE    transfer  473.98
# 3 2025-06-09 18:02:31    90782     FR     payment   17.49
# 4 2025-06-07 14:49:15   442919     UK     payment  104.86
# 5 2025-11-09 12:42:41   478495     UK     payment    8.32
# 6 2025-02-01 06:49:15   461269     FR     payment   39.74
# 7 2025-09-11 20:12:25    84558     UK    transfer   99.12
# 8 2025-03-15 08:02:16   433528     FR  withdrawal   45.27
# 9 2025-02-04 06:43:59   394418     IT     payment   14.39
#
#                                              payload
# 0   merchant=Apple;category=electronics;currency=CHF
# 1  merchant=Netflix;category=subscription;currenc...
# 2  merchant=Netflix;category=subscription;currenc...
# 3       merchant=SBB;category=transport;currency=EUR
# 4      merchant=Coop;category=groceries;currency=GBP
# ...

# %%
print(df["payload"].head())
# Out:
# 0     merchant=Apple;category=electronics;currency=CHF
# 1    merchant=Netflix;category=subscription;currenc...
# 2    merchant=Netflix;category=subscription;currenc...
# 3         merchant=SBB;category=transport;currency=EUR
# 4        merchant=Coop;category=groceries;currency=GBP
# Name: payload, dtype: object
